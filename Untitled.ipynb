# %%
print('Hello, world!')
# Out:
# Hello, world!

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# Prepare the data
x = np.linspace(0, 10, 100)

# Plot the data
plt.plot(x, np.sin(x))

# Add a legend
plt.legend()

# Show the plot
plt.show()
# Out:
# No handles with labels found to put in legend.
