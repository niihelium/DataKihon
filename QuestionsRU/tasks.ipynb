# %% [markdown]
# # Научный кругозор
# - Какие факторы привели к буму глубокого обучения и определили успех
# использования этой технологии?
# - В чем причина зимы искусственного интеллекта?
#
# # Задачи
# - Предложите алгоритм для нахождения радиуса (в пикселях) и центра зеленого шара, изображенного на фотографии
# - Пусть дано две системы координат - глобальная и локальная. Пусть положение локальной системы в глобальной определяется матрицей поворота R и вектором сдвига 1. Найдите координаты точки р в локальной системе координат, если они известны в глобальной
