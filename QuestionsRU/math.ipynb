# %% [markdown]
# # Математика
# - Что такое СЛАУ? Когда она имеет единственное решение?
# - Что такое линейная независимость векторов?
# - Что такое норма? Каким условиям должна удовлетворять? Что такое L1, L2, L бесконечность нормы? Является ли L0.5 нормой? Почему?
# - При каких условиях существует обратная матрица?
# - Что такое собственное число и собственные вектор матрицы?
# - Какие методы оптимизации вы знаете? В чем суть градиентного спуска?
# - Сформулируйте теорему Байеса
# - Что значит, что данные линейно разделимы?
