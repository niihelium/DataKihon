# %% [markdown]
# # ML
# - Какой из двух нижеследующих алгоритмов более мощен с точки зрения выразительности (например, может представить любую Булеву функцию): однослойный перцептрон или дерево решений глубиной 2?
# - Какой из двух алгоритмов более мощен - двухслойный перцептрон (Румельхарта) с любыми функциями активации или дерево решений глубиной 2?
# - Могут ли нейросети использоваться для задач сокращения размерности? Если да, объясните как.
# - Обратное распространение ошибки - рабочая лошадка глубокого обучения. Назовите несколько способов обучения нейросетей БЕЗ использования обратного распространения ошибки.
# - Почему ньютоновские и квазиньютоновские алгоритмы оптимизации не используют для обучения глубоких нейросетей?
# - Объясните bias-variance tradeoff
# - Что такое сверточные нейронные сети? Где и как их используют? Что такое data augmentation? Приведите несколько примеров.
# - Почему наивный Байес "наивный"?
# - Какую задачу оптимизации решает SVM?
# - В чем плюсы и минусы SVM?
# - Можно ли использовать SVM, если данные линейно неразделимы? Если да, то как?
